# %% [markdown]
# # Cleaning Data

# %% [markdown]
# The data sets that we have come with a lot of stats about the players. In this step we are going through and removing players that didn't come from the NCAA (Europe) and trimming down the attributes to the things that we believe are important.

# %%
import operator
import random
import math
import numpy as np

def get_table(filename):
    table = []
    infile = open(filename)
    lines = infile.readlines()
    
    i = 0
    for line in lines:
        add_it = True
        line = line.strip()
        line = line.strip('\n')
        values = line.split(",")
       
        #this is only grabbing columns that are completely filled in
        if len(values) > 27:        
            for val in values:
                #Get rid of columns with NA in them
                if val == 'NA':
                    add_it = False
            if add_it:
                
                #player - 6
                #pick - 4
                #MP - 31
                #FG - 32
                #FG% - 34
                #3p - 38
                #3pt% - 40
                #FT - 41
                #PTS - 52
                #SOS - 54
                #NBA PTS - 15
                
                to_add = []
                to_add.append(values[6])
                to_add.append(values[4])
                to_add.append(values[31])
                to_add.append(values[32])
                to_add.append(values[34])
                to_add.append(values[38])
                if values[40] == '':
                    to_add.append(0.0)
                else:
                    to_add.append(values[40])
                to_add.append(values[41])
                to_add.append(values[52])
                to_add.append(values[54])
                to_add.append(values[15])
                convert_to_numeric(to_add)
                table.append(to_add)
    infile.close()
    return table


def convert_to_numeric(values):
    '''
    converts values read from a file into correct types
    '''
    for i in range(len(values)):
        try:
            #converts numerical values from strings to floats
            numeric_val = float(values[i])
            values[i] = numeric_val
        except ValueError:
            values[i] = values[i].strip('\"')

# %% [markdown]
# # Basic KNN_functions

# %% [markdown]
# ## get_column and compute_distances
# Here are 2 helper functions for the KNN algorithm. I have get_frequencies commented out because we currently do not use it

# %%
'''
def get_frequencies(table, column_index):
    get values and counts given a table and 
    the column_index
    column = sorted(get_column(table, column_index))
    values = []
    counts = []
    for value in column:
        if value not in values:
            values.append(value)
            counts.append(1)
        else:
            counts[-1] += 1
    return values, counts
'''

def get_column(table, column_index):
    column = []
    for row in table:
        if row[column_index] != 'NA':
            column.append(row[column_index])
    return column

def compute_distances(v1,v2,table):
    assert(len(v1) == len(v2))

    dist = 0
    for i in range(1, len(v1)-1):
        Min = min(get_column(table, i))
        Max = max(get_column(table, i))
        v1_N = normalize(v1[i], Min, Max)
        v2_N = normalize(v2[i], Min, Max)
    
        dist += (v1_N- v2_N) ** 2
    return math.sqrt(dist)

def normalize(x, Min, Max):
    '''
    normalizes data before distance calculations
    '''
    normalized = ((x - Min) / (Max - Min)) * 1.0
    return normalized

# %% [markdown]
# Here is the knn guess function where i take in the training set and the test set and find its nearest neighbors, compute the avg of the nearest neighbors and return the list of values.

# %%
def knn_guess(train_set, test_set, k_val):
    '''
    classifier using knn given a test set, train set and k value
    '''
    
    init_len = len(train_set)
    
    right = 0
    wrong = 0

    for row in train_set:
        row.append(compute_distances(row, test_set, train_set))  

    k = k_val
    
    length_of_rows = len(train_set[0])
    train_set.sort(key=operator.itemgetter(length_of_rows-1))

    top_k = train_set[:k]

    # calculate the averages from the nearest neighbors
    sum_ppg = 0
    for player in top_k:
        sum_ppg += player[10]
    avg_ppg = sum_ppg/len(top_k)

    for row in train_set:
        row.pop()
    
    return avg_ppg

# %% [markdown]
# Here i created a k-fold that just works for testing

# %%
def k_fold(table):
    randomized = table[:]
    n = len(randomized)

    for i in range(n):
        rand_index = random.randrange(0,n)
        randomized[i], randomized[rand_index] = randomized[rand_index], randomized[i]


    folds = [[] for i in range(10)]
    x = 0
    for i in range(len(randomized)):
        if x > 9:
            x = 0
        folds[x].append(randomized[i])
        x += 1
    return folds

# %% [markdown]
# Here is a the knn function that runs over the folds and outputs the answers.

# %%
def knnPrediction(table, headers):    
    folds = k_fold(table)
    print("---------------------")
    print("Self-Coded: KNN")
    print("---------------------")
    differences = []
    for i in range(len(folds)):
        train_set = []

        for x in folds:
            if x != folds[i]:
                for item in x:
                    train_set.append(item)
        for j in folds[i]:
            my_guess = knn_guess(train_set, j, 10)
            print ("Player: " + j[0])
            print ("NBA PPG: " + str(j[10]))
            print ("predicted PPG: " + str(my_guess))
            diff = j[10] - my_guess
            differences.append(abs(diff))
    print("-----------------------------------------------------------------------------")
    print ("average error: " + str(np.mean(differences)))
    print ("median error: " + str(np.median(differences)))

# %% [markdown]
# This function outputs a table of correelation coefficents for all the attributes we used for our kNN classifier

# %%
def find_stat_correlation_to_NBA_PTS(table, headers):
    NBA_PTS = get_column(table, 10)
    for i in range(1, len(headers)-1):
        cur_column = get_column(table, i)
        vals = np.corrcoef(cur_column, NBA_PTS)
        r = str(vals[0][-1])
        print (headers[i] + " correlation coefficent = " + r)

# %%
#fxn that calls KNN-self-done

start_table = get_table('datasets/firstRoundPicks_withCollegeStats.csv')
headers = start_table[0]
table = start_table[1:]
    
knnPrediction(table, headers)
find_stat_correlation_to_NBA_PTS(table, headers)
# Out:
# ---------------------
# Self-Coded: KNN
# ---------------------
# Player: Stanley Johnson\johnsst04
# NBA PPG: 6.9
# predicted PPG: 10.209999999999997
# Player: Deandre Ayton\aytonde01
# NBA PPG: 16.3
# predicted PPG: 12.239999999999998
# Player: Kevin Knox\knoxke01
# NBA PPG: 12.7
# predicted PPG: 9.95
# Player: Joel Embiid\embiijo01
# NBA PPG: 24.2
# predicted PPG: 10.17
# Player: Josh Jackson\jacksjo02
# NBA PPG: 12.1
# predicted PPG: 12.15
# Player: Terry Rozier\roziete01
# NBA PPG: 7.7
# predicted PPG: 8.200000000000001
# Player: Jacob Evans\evansja02
# NBA PPG: 0.8
# predicted PPG: 6.159999999999999
# Player: Aaron Gordon\gordoaa01
# NBA PPG: 12.4
# predicted PPG: 8.85
# Player: Lonzo Ball\balllo01
# NBA PPG: 10.0
# predicted PPG: 10.629999999999999
# Player: Josh Okogie\okogijo01
# NBA PPG: 7.9
# predicted PPG: 6.210000000000001
# Player: Nik Stauskas\stausni01
# NBA PPG: 6.8
# predicted PPG: 10.96
# Player: Kevon Looney\looneke01
# NBA PPG: 4.4
# predicted PPG: 5.14
# Player: Robert Williams\williro04
# NBA PPG: 2.5
# predicted PPG: 8.15
# Player: Moritz Wagner\wagnemo01
# NBA PPG: 4.4
# predicted PPG: 5.61
# Player: Malachi Richardson\richama01
# NBA PPG: 2.8
# predicted PPG: 6.25
# Player: T.J. Leaf\leaftj01
# NBA PPG: 3.2
# predicted PPG: 6.1
# Player: Jerian Grant\grantje02
# NBA PPG: 6.1
# predicted PPG: 6.470000000000001
# Player: Bobby Portis\portibo01
# NBA PPG: 10.2
# predicted PPG: 4.69
# Player: Lonnie Walker\walkelo01
# NBA PPG: 1.8
# predicted PPG: 10.16
# Player: Harry Giles\gilesha01
# NBA PPG: 7.0
# predicted PPG: 6.380000000000001
# Player: Devin Booker\bookede01
# NBA PPG: 21.4
# predicted PPG: 11.34
# Player: Bam Adebayo\adebaba01
# NBA PPG: 7.9
# predicted PPG: 10.43
# Player: Rashad Vaughn\vaughra01
# NBA PPG: 3.0
# predicted PPG: 6.910000000000001
# Player: Omari Spellman\spellom01
# NBA PPG: 5.9
# predicted PPG: 6.36
# Player: T.J. Warren\warretj01
# NBA PPG: 14.4
# predicted PPG: 9.439999999999998
# Player: P.J. Hairston\hairspj02
# NBA PPG: 6.0
# predicted PPG: 8.639999999999999
# Player: Noah Vonleh\vonleno01
# NBA PPG: 5.1
# predicted PPG: 9.140000000000002
# Player: Caris LeVert\leverca01
# NBA PPG: 11.1
# predicted PPG: 7.499999999999998
# Player: Pascal Siakam\siakapa01
# NBA PPG: 9.9
# predicted PPG: 6.880000000000001
# Player: R.J. Hunter\hunterj01
# NBA PPG: 2.6
# predicted PPG: 5.1
# Player: Markelle Fultz\fultzma01
# NBA PPG: 7.7
# predicted PPG: 11.559999999999999
# Player: Kris Dunn\dunnkr01
# NBA PPG: 8.6
# predicted PPG: 10.53
# Player: Zach Collins\colliza01
# NBA PPG: 5.5
# predicted PPG: 10.04
# Player: De'Aaron Fox\foxde01
# NBA PPG: 14.6
# predicted PPG: 12.979999999999999
# Player: Jamal Murray\murraja01
# NBA PPG: 14.8
# predicted PPG: 10.98
# Player: Zhaire Smith\smithzh01
# NBA PPG: 1.5
# predicted PPG: 7.35
# Player: Jaylen Brown\brownja02
# NBA PPG: 11.2
# predicted PPG: 12.76
# Player: Jaren Jackson\jacksja02
# NBA PPG: 13.8
# predicted PPG: 11.88
# Player: Marvin Bagley\baglema01
# NBA PPG: 14.7
# predicted PPG: 12.87
# Player: Larry Nance Jr.\nancela02
# NBA PPG: 7.7
# predicted PPG: 5.6899999999999995
# Player: Josh Hart\hartjo01
# NBA PPG: 7.9
# predicted PPG: 4.85
# Player: Donovan Mitchell\mitchdo01
# NBA PPG: 21.9
# predicted PPG: 9.44
# Player: Lauri Markkanen\markkla01
# NBA PPG: 16.7
# predicted PPG: 9.82
# Player: Aaron Holiday\holidaa01
# NBA PPG: 5.6
# predicted PPG: 5.37
# Player: Wade Baldwin\baldwwa01
# NBA PPG: 3.1
# predicted PPG: 6.369999999999999
# Player: Mitch McGary\mcgarmi01
# NBA PPG: 4.4
# predicted PPG: 6.7700000000000005
# Player: Malik Monk\monkma01
# NBA PPG: 8.0
# predicted PPG: 11.260000000000002
# Player: Rondae Hollis-Jefferson\holliro01
# NBA PPG: 9.9
# predicted PPG: 6.7299999999999995
# Player: Tony Bradley\bradlto01
# NBA PPG: 0.8
# predicted PPG: 7.25
# Player: Elfrid Payton\paytoel01
# NBA PPG: 11.1
# predicted PPG: 6.980000000000001
# Player: Chris McCullough\mcculch01
# NBA PPG: 3.3
# predicted PPG: 4.71
# Player: Wendell Carter\cartewe01
# NBA PPG: 10.3
# predicted PPG: 8.099999999999998
# Player: Kyle Kuzma\kuzmaky01
# NBA PPG: 17.3
# predicted PPG: 5.87
# Player: Justin Patton\pattoju01
# NBA PPG: 1.8
# predicted PPG: 6.09
# Player: Mikal Bridges\bridgmi01
# NBA PPG: 8.2
# predicted PPG: 9.76
# Player: Miles Bridges\bridgmi02
# NBA PPG: 7.1
# predicted PPG: 9.58
# Player: Zach LaVine\lavinza01
# NBA PPG: 16.1
# predicted PPG: 10.629999999999999
# Player: Malik Beasley\beaslma01
# NBA PPG: 7.0
# predicted PPG: 5.0600000000000005
# Player: Luke Kennard\kennalu01
# NBA PPG: 8.5
# predicted PPG: 9.16
# Player: OG Anunoby\anunoog01
# NBA PPG: 6.5
# predicted PPG: 4.9399999999999995
# Player: Gary Harris\harriga01
# NBA PPG: 12.4
# predicted PPG: 4.95
# Player: Henry Ellenson\ellenhe01
# NBA PPG: 4.0
# predicted PPG: 6.319999999999999
# Player: Justin Jackson\jacksju01
# NBA PPG: 6.7
# predicted PPG: 8.510000000000002
# Player: Karl-Anthony Towns\townska01
# NBA PPG: 22.2
# predicted PPG: 10.569999999999999
# Player: Damian Jones\jonesda03
# NBA PPG: 3.6
# predicted PPG: 6.2
# Player: Collin Sexton\sextoco01
# NBA PPG: 16.6
# predicted PPG: 13.680000000000001
# Player: Jarrett Allen\allenja01
# NBA PPG: 9.6
# predicted PPG: 5.569999999999999
# Player: Brandon Ingram\ingrabr01
# NBA PPG: 13.9
# predicted PPG: 13.9
# Player: Landry Shamet\shamela01
# NBA PPG: 9.1
# predicted PPG: 5.4399999999999995
# Player: Myles Turner\turnemy01
# NBA PPG: 12.9
# predicted PPG: 12.02
# Player: Jonathan Isaac\isaacjo01
# NBA PPG: 8.4
# predicted PPG: 8.52
# Player: Brice Johnson\johnsbr02
# NBA PPG: 2.2
# predicted PPG: 6.85
# Player: John Collins\collijo01
# NBA PPG: 14.4
# predicted PPG: 7.730000000000001
# Player: Julius Randle\randlju01
# NBA PPG: 15.3
# predicted PPG: 11.06
# Player: Doug McDermott\mcderdo01
# NBA PPG: 7.8
# predicted PPG: 10.59
# Player: Kyle Anderson\anderky01
# NBA PPG: 5.3
# predicted PPG: 4.85
# Player: Cameron Payne\payneca01
# NBA PPG: 6.0
# predicted PPG: 7.42
# Player: Caleb Swanigan\swanica01
# NBA PPG: 2.1
# predicted PPG: 6.040000000000001
# Player: Trey Lyles\lylestr01
# NBA PPG: 7.6
# predicted PPG: 10.080000000000002
# Player: C.J. Wilcox\wilcocj01
# NBA PPG: 2.0
# predicted PPG: 6.45
# Player: Marquese Chriss\chrisma01
# NBA PPG: 7.6
# predicted PPG: 8.209999999999999
# Player: Jerome Robinson\robinje01
# NBA PPG: 3.1
# predicted PPG: 8.629999999999999
# Player: Jordan Adams\adamsjo01
# NBA PPG: 3.2
# predicted PPG: 6.07
# Player: Frank Kaminsky\kaminfr01
# NBA PPG: 9.6
# predicted PPG: 11.67
# Player: D.J. Wilson\wilsodj01
# NBA PPG: 3.9
# predicted PPG: 10.059999999999999
# Player: Trae Young\youngtr01
# NBA PPG: 18.9
# predicted PPG: 13.459999999999999
# Player: Josh Huestis\huestjo01
# NBA PPG: 2.5
# predicted PPG: 7.089999999999999
# Player: Dennis Smith\smithde03
# NBA PPG: 14.4
# predicted PPG: 13.290000000000001
# Player: Marcus Smart\smartma01
# NBA PPG: 9.3
# predicted PPG: 13.6
# Player: Tyus Jones\jonesty01
# NBA PPG: 4.9
# predicted PPG: 5.26
# Player: Buddy Hield\hieldbu01
# NBA PPG: 14.9
# predicted PPG: 10.8
# Player: Grayson Allen\allengr01
# NBA PPG: 3.8
# predicted PPG: 5.54
# Player: Jahlil Okafor\okafoja01
# NBA PPG: 11.3
# predicted PPG: 12.379999999999999
# Player: Jakob Poeltl\poeltja01
# NBA PPG: 5.4
# predicted PPG: 12.78
# Player: Domantas Sabonis\sabondo01
# NBA PPG: 10.3
# predicted PPG: 6.580000000000001
# Player: Adreian Payne\paynead01
# NBA PPG: 4.0
# predicted PPG: 8.400000000000002
# Player: Tyler Lydon\lydonty01
# NBA PPG: 0.8
# predicted PPG: 7.090000000000001
# Player: Denzel Valentine\valende01
# NBA PPG: 8.0
# predicted PPG: 9.400000000000002
# Player: Kelly Oubre\oubreke01
# NBA PPG: 9.4
# predicted PPG: 12.069999999999999
# Player: Delon Wright\wrighde01
# NBA PPG: 7.1
# predicted PPG: 6.8100000000000005
# Player: Justin Anderson\anderju01
# NBA PPG: 5.3
# predicted PPG: 9.19
# Player: Rodney Hood\hoodro01
# NBA PPG: 12.6
# predicted PPG: 4.499999999999999
# Player: Skal Labissiere\labissk01
# NBA PPG: 7.5
# predicted PPG: 5.15
# Player: Sam Dekker\dekkesa01
# NBA PPG: 5.4
# predicted PPG: 8.24
# Player: Shabazz Napier\napiesh01
# NBA PPG: 6.4
# predicted PPG: 4.89
# Player: Troy Brown\browntr01
# NBA PPG: 4.4
# predicted PPG: 9.319999999999999
# Player: DeAndre Bembry\bembrde01
# NBA PPG: 6.1
# predicted PPG: 5.89
# Player: Jayson Tatum\tatumja01
# NBA PPG: 14.9
# predicted PPG: 14.479999999999999
# Player: Justise Winslow\winslju01
# NBA PPG: 8.9
# predicted PPG: 10.05
# Player: Derrick White\whitede01
# NBA PPG: 8.3
# predicted PPG: 5.6899999999999995
# Player: Donte DiVincenzo\divindo01
# NBA PPG: 4.9
# predicted PPG: 11.45
# Player: Chandler Hutchison\hutchch01
# NBA PPG: 5.2
# predicted PPG: 6.959999999999999
# Player: Mohamed Bamba\bambamo01
# NBA PPG: 6.2
# predicted PPG: 10.809999999999999
# Player: D'Angelo Russell\russeda01
# NBA PPG: 16.4
# predicted PPG: 11.55
# Player: Ben Simmons\simmobe01
# NBA PPG: 16.4
# predicted PPG: 13.850000000000003
# Player: Tyler Ennis\ennisty01
# NBA PPG: 4.2
# predicted PPG: 6.09
# Player: Kevin Huerter\huertke01
# NBA PPG: 9.5
# predicted PPG: 6.390000000000001
# Player: Jarell Martin\martija01
# NBA PPG: 5.5
# predicted PPG: 5.4799999999999995
# Player: Dejounte Murray\murrade01
# NBA PPG: 6.6
# predicted PPG: 6.19
# Player: James Young\youngja01
# NBA PPG: 2.3
# predicted PPG: 6.760000000000001
# Player: Willie Cauley-Stein\caulewi01
# NBA PPG: 10.1
# predicted PPG: 10.889999999999999
# Player: Jabari Parker\parkeja01
# NBA PPG: 15.1
# predicted PPG: 13.64
# Player: Shai Gilgeous-Alexander\gilgesh01
# NBA PPG: 10.6
# predicted PPG: 11.080000000000002
# Player: Andrew Wiggins\wiggian01
# NBA PPG: 19.4
# predicted PPG: 12.830000000000002
# Player: Taurean Prince\princta02
# NBA PPG: 11.3
# predicted PPG: 11.170000000000002
# -----------------------------------------------------------------------------
# average error: 3.32864
# median error: 2.84
# Pk correlation coefficent = -0.5994202468383477
# MP correlation coefficent = 0.0629618794699425
# FG correlation coefficent = 0.2517030362074402
# FG% correlation coefficent = 0.0556473898095536
# 3P correlation coefficent = 0.027406926749840865
# 3P% correlation coefficent = -0.0555737387878667
# FT correlation coefficent = 0.31986899198272084
# PTS correlation coefficent = 0.2854142645696732
# SOS correlation coefficent = 0.18660066639267506

# %% [markdown]
# # Scikit-learn

# %%
#from sklearn.neighbors import KNeighborsClassifier
#n = KNeighborsClassifier(n_neighbors = 5)
#once we have the data, then X is our training data and Y is our target values

#n.fit(X, y)
#print(n.predict[[test_dealio]])
